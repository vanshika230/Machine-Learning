# %%
import cv2

# %%
# Read an Image
img = cv2.imread('me.jpg')

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img) #default is in bgr format
plt.show()

# %%
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newImg)  #rgb format - original photo
plt.show()
